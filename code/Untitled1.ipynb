# %%
import pandas as pd
import numpy as  np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot

# %%
plt.rc("font",family = "AppleGothic")

# %%
df = pd.read_excel('./data/노인복지시설(2020).xls' )

# %%
df.shape
# Out:
# (27, 7)

# %%
del df['기간']
df.drop([0],inplace=True)
df.set_index('자치구', inplace=True)
df.rename(columns={'노인복지관.1' : '종사자수'},
                       index={'합계':'서울시'}, inplace=True)
df.head()
# Out:
#      시설합계 노인복지관  종사자수   경로당 노인교실
# 자치구
# 서울시  3910    83  2225  3472  355
# 종로구    75     3   111    63    9
# 중구     54     2    66    48    4
# 용산구   110     2    75    88   20
# 성동구   179     4    82   162   13

# %%
plt.figure()
df['노인복지관'].sort_values().plot(kind='barh', grid=True, figsize=(15,10))
plt.xlabel('노인복지관수')
plt.show()

# %%
plt.figure()
df['종사자수'].sort_values().plot(kind='barh', grid=True, figsize=(15,10))
plt.xlabel('종사자수')
plt.show()

# %%
plt.figure()
df['경로당'].sort_values().plot(kind='barh', grid=True, figsize=(15,10))
plt.xlabel('경로당')
plt.show()

# %%
plt.figure()
df['시설합계'].sort_values().plot(kind='barh', grid=True, figsize=(15,10))
plt.xlabel('경로당')
plt.show()

# %%
Senior_Population = pd.read_excel('./data/독거노인 .xls')
Senior_Population.head()
# Out:
#      기간   구분      합계    합계.1    합계.2 국민기초생활보장수급권자 국민기초생활보장수급권자.1  \
# 0    기간   구분       계  65~79세  80세 이상            계         65~79세
# 1  2020   합계  366134  275574   90560        92446          64798
# 2  2020  종로구    9648    6814    2834         1663           1260
# 3  2020   중구    7117    5272    1845         1872           1371
# 4  2020  용산구   10354    7347    3007         2421           1723
#
#   국민기초생활보장수급권자.2  저소득노인 저소득노인.1 저소득노인.2      일반    일반.1    일반.2
# 0         80세 이상      계  65~79세  80세 이상       계  65~79세  80세 이상
# 1          27648  19535   11629    7906  254153  199147   55006
# 2            403    377     220     157    7608    5334    2274
# 3            501    308     170     138    4937    3731    1206
# 4            698    247     135     112    7686    5489    2197

# %%
del Senior_Population['기간']
del Senior_Population['합계.1']
del Senior_Population['합계.2']
del Senior_Population['국민기초생활보장수급권자.1']
del Senior_Population['국민기초생활보장수급권자.2']
del Senior_Population['저소득노인.1']
del Senior_Population['저소득노인.2']
del Senior_Population['일반.1']
del Senior_Population['일반.2']
Senior_Population.drop([0],inplace=True)
Senior_Population.rename(columns={'일반' : '나머지','구분' : '자치구'}, inplace=True)
Senior_Population.set_index('자치구', inplace=True)
Senior_Population.rename(index={'합계':'서울시'}, inplace=True)

Senior_Population['기초수급노인'] = Senior_Population['국민기초생활보장수급권자']+Senior_Population['저소득노인']
del Senior_Population['국민기초생활보장수급권자']
del Senior_Population['저소득노인']
Senior_Population.head()
# Out:
#          합계     나머지  기초수급노인
# 자치구
# 서울시  366134  254153  111981
# 종로구    9648    7608    2040
# 중구     7117    4937    2180
# 용산구   10354    7686    2668
# 성동구   14036   10662    3374

# %%
Senior_medical_facility = pd.read_excel('./data/노인의료시설(2020).xls')
Senior_medical_facility.head()
# Out:
#      기간  자치구   합계   합계.1   합계.2  합계.3 노인요양시설 노인요양시설.1 노인요양시설.2 노인요양시설.3  \
# 0    기간  자치구  시설수   입소인원   입소인원  종사자수    시설수     입소인원     입소인원     종사자수
# 1    기간  자치구  시설수     정원     현원  종사자수    시설수       정원       현원     종사자수
# 2  2020   합계  508  15467  13962  9680    212    12873    11571     7885
# 3  2020  종로구   10    364    340   258      8      347      325      245
# 4  2020   중구    3     83     81    68      2       74       72       61
#
#   노인요양 공동 생활가정 노인요양 공동 생활가정.1 노인요양 공동 생활가정.2 노인요양 공동 생활가정.3
# 0          시설수           입소인원           입소인원           종사자수
# 1          시설수             정원             현원           종사자수
# 2          296           2594           2391           1795
# 3            2             17             15             13
# 4            1              9              9              7

# %%
del Senior_medical_facility ['합계.1']
del Senior_medical_facility ['합계.2']
del Senior_medical_facility ['노인요양시설.1']
del Senior_medical_facility ['노인요양시설.2']
# del Senior_medical_facility ['노인요양 공동 생활가정.1']
# del Senior_medical_facility ['노인 요양 공동생활가정.2']

Senior_medical_facility.rename(index={'합계':'서울시'}, inplace=True)

# %%
Senior_medical_facility
Senior_medical_facility.drop([0],inplace=True)
del Senior_medical_facility ['노인요양 공동 생활가정.2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ht/4d122qr50vs5jr5k781my7yr0000gn/T/ipykernel_68390/4095562344.py in <module>
#       1 Senior_medical_facility
# ----> 2 Senior_medical_facility.drop([0],inplace=True)
#       3 del Senior_medical_facility ['노인요양 공동 생활가정.2']
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4946                 weight  1.0     0.8
#    4947         """
# -> 4948         return super().drop(
#    4949             labels=labels,
#    4950             axis=axis,
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277         for axis, labels in axes.items():
#    4278             if labels is not None:
# -> 4279                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4280
#    4281         if inplace:
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4322             else:
# -> 4323                 new_axis = axis.drop(labels, errors=errors)
#    4324             indexer = axis.get_indexer(new_axis)
#    4325
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6642         if mask.any():
#    6643             if errors != "ignore":
# -> 6644                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645             indexer = indexer[~mask]
#    6646         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
del Senior_medical_facility ['노인요양 공동 생활가정.2']

# %%
Senior_medical_facility
# Out:
#      자치구   합계  합계.3 노인요양시설 노인요양시설.3 노인요양 공동 생활가정 노인요양 공동 생활가정.3
# 1    자치구  시설수  종사자수    시설수     종사자수          시설수           종사자수
# 2     합계  508  9680    212     7885          296           1795
# 3    종로구   10   258      8      245            2             13
# 4     중구    3    68      2       61            1              7
# 5    용산구    4   143      3      136            1              7
# 6    성동구    6   251      3      234            3             17
# 7    광진구   20   368      8      295           12             73
# 8   동대문구   25   264      4      140           21            124
# 9    중랑구   48   740     10      512           38            228
# 10   성북구   21   431     16      400            5             31
# 11   강북구   31   462      8      322           23            140
# 12   도봉구   55   725     21      518           34            207
# 13   노원구   32   661     11      533           21            128
# 14   은평구   22   683     15      639            7             44
# 15  서대문구   18   292     10      247            8             45
# 16   마포구    4   213      2      201            2             12
# 17   양천구   21   485     13      438            8             47
# 18   강서구   31   687     18      619           13             68
# 19   구로구   17   539     10      499            7             40
# 20   금천구   25   466     12      384           13             82
# 21  영등포구   18   190      1       87           17            103
# 22   동작구   10   160      3      117            7             43
# 23   관악구   28   416     10      296           18            120
# 24   서초구    5   221      4      215            1              6
# 25   강남구    7    69      4       48            3             21
# 26   송파구   23   539      8      441           15             98
# 27   강동구   24   349      8      258           16             91

# %%
Senior_medical_facility.rename(columns={'노인요양시설' : '노인요양시설수','노인요양시설.3' : '노인요양시설종사자수'}, inplace=True)

# %%
Senior_medical_facility.rename(columns={'노인요양 공동 생활가정' : '노인요양 공동 생활가정수','노인요양 공동 생활가정.3' : '노인요양 공동 생활가정 종사자수'}, inplace=True)

# %%
Senior_medical_facility
# Out:
#      자치구   합계  합계.3 노인요양시설수 노인요양시설종사자수 노인요양 공동 생활가정수 노인요양 공동 생활가정 종사자수
# 2     합계  508  9680     212       7885           296              1795
# 3    종로구   10   258       8        245             2                13
# 4     중구    3    68       2         61             1                 7
# 5    용산구    4   143       3        136             1                 7
# 6    성동구    6   251       3        234             3                17
# 7    광진구   20   368       8        295            12                73
# 8   동대문구   25   264       4        140            21               124
# 9    중랑구   48   740      10        512            38               228
# 10   성북구   21   431      16        400             5                31
# 11   강북구   31   462       8        322            23               140
# 12   도봉구   55   725      21        518            34               207
# 13   노원구   32   661      11        533            21               128
# 14   은평구   22   683      15        639             7                44
# 15  서대문구   18   292      10        247             8                45
# 16   마포구    4   213       2        201             2                12
# 17   양천구   21   485      13        438             8                47
# 18   강서구   31   687      18        619            13                68
# 19   구로구   17   539      10        499             7                40
# 20   금천구   25   466      12        384            13                82
# 21  영등포구   18   190       1         87            17               103
# 22   동작구   10   160       3        117             7                43
# 23   관악구   28   416      10        296            18               120
# 24   서초구    5   221       4        215             1                 6
# 25   강남구    7    69       4         48             3                21
# 26   송파구   23   539       8        441            15                98
# 27   강동구   24   349       8        258            16                91

# %%
Senior_medical_facility.rename(index={'합계':'서울시'}, inplace=True)

# %%
Senior_medical_facility.drop([1],inplace=True)

# %%
Senior_medical_facility
# Out:
#      자치구   합계  합계.3 노인요양시설수 노인요양시설종사자수 노인요양 공동 생활가정수 노인요양 공동 생활가정 종사자수
# 2     합계  508  9680     212       7885           296              1795
# 3    종로구   10   258       8        245             2                13
# 4     중구    3    68       2         61             1                 7
# 5    용산구    4   143       3        136             1                 7
# 6    성동구    6   251       3        234             3                17
# 7    광진구   20   368       8        295            12                73
# 8   동대문구   25   264       4        140            21               124
# 9    중랑구   48   740      10        512            38               228
# 10   성북구   21   431      16        400             5                31
# 11   강북구   31   462       8        322            23               140
# 12   도봉구   55   725      21        518            34               207
# 13   노원구   32   661      11        533            21               128
# 14   은평구   22   683      15        639             7                44
# 15  서대문구   18   292      10        247             8                45
# 16   마포구    4   213       2        201             2                12
# 17   양천구   21   485      13        438             8                47
# 18   강서구   31   687      18        619            13                68
# 19   구로구   17   539      10        499             7                40
# 20   금천구   25   466      12        384            13                82
# 21  영등포구   18   190       1         87            17               103
# 22   동작구   10   160       3        117             7                43
# 23   관악구   28   416      10        296            18               120
# 24   서초구    5   221       4        215             1                 6
# 25   강남구    7    69       4         48             3                21
# 26   송파구   23   539       8        441            15                98
# 27   강동구   24   349       8        258            16                91

# %%
Senior_medical_facility.set_index('자치구', inplace=True)
Senior_medical_facility.rename(index={'합계':'서울시'}, inplace=True)

# %%
Senior_medical_facility
# Out:
#        합계  합계.3 노인요양시설수 노인요양시설종사자수 노인요양 공동 생활가정수 노인요양 공동 생활가정 종사자수
# 자치구
# 서울시   508  9680     212       7885           296              1795
# 종로구    10   258       8        245             2                13
# 중구      3    68       2         61             1                 7
# 용산구     4   143       3        136             1                 7
# 성동구     6   251       3        234             3                17
# 광진구    20   368       8        295            12                73
# 동대문구   25   264       4        140            21               124
# 중랑구    48   740      10        512            38               228
# 성북구    21   431      16        400             5                31
# 강북구    31   462       8        322            23               140
# 도봉구    55   725      21        518            34               207
# 노원구    32   661      11        533            21               128
# 은평구    22   683      15        639             7                44
# 서대문구   18   292      10        247             8                45
# 마포구     4   213       2        201             2                12
# 양천구    21   485      13        438             8                47
# 강서구    31   687      18        619            13                68
# 구로구    17   539      10        499             7                40
# 금천구    25   466      12        384            13                82
# 영등포구   18   190       1         87            17               103
# 동작구    10   160       3        117             7                43
# 관악구    28   416      10        296            18               120
# 서초구     5   221       4        215             1                 6
# 강남구     7    69       4         48             3                21
# 송파구    23   539       8        441            15                98
# 강동구    24   349       8        258            16                91

# %%
plt.figure()
Senior_medical_facility['노인요양시설수'].sort_values().plot(kind='barh', grid=True, figsize=(15,10))
plt.xlabel('노인요양시설수')
plt.show()

# %%
plt.figure()
Senior_medical_facility['노인요양 공동 생활가정 종사자수'].sort_values().plot(kind='barh', grid=True, figsize=(15,10))
plt.xlabel('노인요양 공동 생활가정 종사자수')
plt.show()

# %%
TotalData = pd.merge(Senior_Population,df , on='자치구')

# %%
TotalData =pd.merge(TotalData, Senior_medical_facility , on='자치구')

# %%
TotalData
# Out:
#         합계_x     나머지  기초수급노인  시설합계 노인복지관  종사자수   경로당 노인교실 합계_y  합계.3 노인요양시설수  \
# 자치구
# 서울시   366134  254153  111981  3910    83  2225  3472  355  508  9680     212
# 종로구     9648    7608    2040    75     3   111    63    9   10   258       8
# 중구      7117    4937    2180    54     2    66    48    4    3    68       2
# 용산구    10354    7686    2668   110     2    75    88   20    4   143       3
# 성동구    14036   10662    3374   179     4    82   162   13    6   251       3
# 광진구    11403    8220    3183   106     1    63    95   10   20   368       8
# 동대문구   16102   10840    5262   151     1    41   134   16   25   264       4
# 중랑구    17946   11026    6920   143     5   156   127   11   48   740      10
# 성북구    17225   12260    4965   190     6   110   175    9   21   431      16
# 강북구    17086   10673    6413   118     1    35   100   17   31   462       8
# 도봉구    13980    9809    4171   149     5    95   135    9   55   725      21
# 노원구    21899   12153    9746   259     3   125   243   13   32   661      11
# 은평구    19437   16345    3092   178     7   170   154   17   22   683      15
# 서대문구   12349    8883    3466   127     4    96   111   12   18   292      10
# 마포구    12545    9292    3253   169     4    70   154   11    4   213       2
# 양천구    14098    9302    4796   191     4   142   164   23   21   485      13
# 강서구    20897   12489    8408   248     5    97   218   25   31   687      18
# 구로구    14924   10775    4149   221     2    44   199   20   17   539      10
# 금천구    10220    6426    3794    83     3   113    73    7   25   466      12
# 영등포구   13868    9859    4009   202     1    27   174   27   18   190       1
# 동작구    14595   10398    4197   151     3    63   140    8   10   160       3
# 관악구    21349   14568    6781   134     1    33   114   19   28   416      10
# 서초구     9553    7511    2042   151     4   130   141    6    5   221       4
# 강남구    13592    8851    4741   195     6    94   167   22    7    69       4
# 송파구    17340   13406    3934   192     3    48   172   17   23   539       8
# 강동구    14571   10174    4397   134     3   139   121   10   24   349       8
#
#      노인요양시설종사자수 노인요양 공동 생활가정수 노인요양 공동 생활가정 종사자수
# 자치구
# 서울시        7885           296              1795
# 종로구         245             2                13
# 중구           61             1                 7
# 용산구         136             1                 7
# 성동구         234             3                17
# 광진구         295            12                73
# 동대문구        140            21               124
# 중랑구         512            38               228
# 성북구         400             5                31
# 강북구         322            23               140
# 도봉구         518            34               207
# 노원구         533            21               128
# 은평구         639             7                44
# 서대문구        247             8                45
# 마포구         201             2                12
# 양천구         438             8                47
# 강서구         619            13                68
# 구로구         499             7                40
# 금천구         384            13                82
# 영등포구         87            17               103
# 동작구         117             7                43
# 관악구         296            18               120
# 서초구         215             1                 6
# 강남구          48             3                21
# 송파구         441            15                98
# 강동구         258            16                91

# %%
# TotalData['1인당 복지수준'] = TotalData['총 복지시설 수']  / TotalData['합계_x']
# TotalData['기초수급노인 비율'] = TotalData['기초수급노인 수']  / TotalData['합계_x']
# TotalData['복지시설 수준'] = TotalData['복지시설 종사자 수']  / TotalData['총 복지시설 수']

# TotalData.drop(['서울시'],inplace=True)
# TotalData = TotalData.applymap(lambda x: float(x))
# TotalData.head()

del TotalData ['노인요양시설수']
del TotalData ['노인요양시설종사자수']
del TotalData ['노인요양 공동 생활가정수']
del TotalData ['노인요양 공동 생활가정 종사자수']

# %%
TotalData
# Out:
#         합계_x     나머지  기초수급노인  시설합계 노인복지관  종사자수   경로당 노인교실 합계_y  합계.3
# 자치구
# 서울시   366134  254153  111981  3910    83  2225  3472  355  508  9680
# 종로구     9648    7608    2040    75     3   111    63    9   10   258
# 중구      7117    4937    2180    54     2    66    48    4    3    68
# 용산구    10354    7686    2668   110     2    75    88   20    4   143
# 성동구    14036   10662    3374   179     4    82   162   13    6   251
# 광진구    11403    8220    3183   106     1    63    95   10   20   368
# 동대문구   16102   10840    5262   151     1    41   134   16   25   264
# 중랑구    17946   11026    6920   143     5   156   127   11   48   740
# 성북구    17225   12260    4965   190     6   110   175    9   21   431
# 강북구    17086   10673    6413   118     1    35   100   17   31   462
# 도봉구    13980    9809    4171   149     5    95   135    9   55   725
# 노원구    21899   12153    9746   259     3   125   243   13   32   661
# 은평구    19437   16345    3092   178     7   170   154   17   22   683
# 서대문구   12349    8883    3466   127     4    96   111   12   18   292
# 마포구    12545    9292    3253   169     4    70   154   11    4   213
# 양천구    14098    9302    4796   191     4   142   164   23   21   485
# 강서구    20897   12489    8408   248     5    97   218   25   31   687
# 구로구    14924   10775    4149   221     2    44   199   20   17   539
# 금천구    10220    6426    3794    83     3   113    73    7   25   466
# 영등포구   13868    9859    4009   202     1    27   174   27   18   190
# 동작구    14595   10398    4197   151     3    63   140    8   10   160
# 관악구    21349   14568    6781   134     1    33   114   19   28   416
# 서초구     9553    7511    2042   151     4   130   141    6    5   221
# 강남구    13592    8851    4741   195     6    94   167   22    7    69
# 송파구    17340   13406    3934   192     3    48   172   17   23   539
# 강동구    14571   10174    4397   134     3   139   121   10   24   349

# %%
TotalData.rename(columns= {'합계.3':'요양시설 종사자수'}, inplace=True)
#                        {'합계_y':'노인 요양 시설수'}, {'합계.3':'요양시설 종사자수'}, inplace=True)

# %%
TotalData
# Out:
#      노인 총 인구 수     나머지  기초수급노인  시설합계 노인복지관  종사자수   경로당 노인교실 노인 요양 시설수  \
# 자치구
# 서울시     366134  254153  111981  3910    83  2225  3472  355       508
# 종로구       9648    7608    2040    75     3   111    63    9        10
# 중구        7117    4937    2180    54     2    66    48    4         3
# 용산구      10354    7686    2668   110     2    75    88   20         4
# 성동구      14036   10662    3374   179     4    82   162   13         6
# 광진구      11403    8220    3183   106     1    63    95   10        20
# 동대문구     16102   10840    5262   151     1    41   134   16        25
# 중랑구      17946   11026    6920   143     5   156   127   11        48
# 성북구      17225   12260    4965   190     6   110   175    9        21
# 강북구      17086   10673    6413   118     1    35   100   17        31
# 도봉구      13980    9809    4171   149     5    95   135    9        55
# 노원구      21899   12153    9746   259     3   125   243   13        32
# 은평구      19437   16345    3092   178     7   170   154   17        22
# 서대문구     12349    8883    3466   127     4    96   111   12        18
# 마포구      12545    9292    3253   169     4    70   154   11         4
# 양천구      14098    9302    4796   191     4   142   164   23        21
# 강서구      20897   12489    8408   248     5    97   218   25        31
# 구로구      14924   10775    4149   221     2    44   199   20        17
# 금천구      10220    6426    3794    83     3   113    73    7        25
# 영등포구     13868    9859    4009   202     1    27   174   27        18
# 동작구      14595   10398    4197   151     3    63   140    8        10
# 관악구      21349   14568    6781   134     1    33   114   19        28
# 서초구       9553    7511    2042   151     4   130   141    6         5
# 강남구      13592    8851    4741   195     6    94   167   22         7
# 송파구      17340   13406    3934   192     3    48   172   17        23
# 강동구      14571   10174    4397   134     3   139   121   10        24
#
#      요양시설 종사자수
# 자치구
# 서울시       9680
# 종로구        258
# 중구          68
# 용산구        143
# 성동구        251
# 광진구        368
# 동대문구       264
# 중랑구        740
# 성북구        431
# 강북구        462
# 도봉구        725
# 노원구        661
# 은평구        683
# 서대문구       292
# 마포구        213
# 양천구        485
# 강서구        687
# 구로구        539
# 금천구        466
# 영등포구       190
# 동작구        160
# 관악구        416
# 서초구        221
# 강남구         69
# 송파구        539
# 강동구        349

# %%
TotalData['1인당 복지수준'] = TotalData['총 복지시설 수']  / TotalData['합계_x']
TotalData['기초수급노인 비율'] = TotalData['기초수급노인 수']  / TotalData['합계_x']
TotalData['복지시설 수준'] = TotalData['복지시설 종사자 수']  / TotalData['총 복지시설 수']

TotalData.drop(['서울시'],inplace=True)
TotalData = TotalData.applymap(lambda x: float(x))
TotalData.head()
